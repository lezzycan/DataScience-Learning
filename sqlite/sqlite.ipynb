# %%
import sqlite3

# %%
connection = sqlite3.connect('example.db')

# %%
cursor = connection.cursor()

# %%
## Create a table
cursor.execute('Create Table If Not Exists users (id INTEGER PRIMARY KEY,name TEXT Not Null, age INTEGER Not Null,department TEXT Not Null)'
               )
               

connection.commit()

# %%
cursor.execute('''
Select * From users               
               
               ''')

# %%
### Insert data in sqlite table
cursor.execute('''
Insert Into users (name, age, department) Values ('Alice', 30, 'HR')

''')

cursor.execute('''
Insert Into users (name, age, department) Values ('Bob', 30, 'CEO')

''')

connection.commit()

# %%
#Query the data from the table

cursor.execute('Select * From users')
rows = cursor.fetchall()


### print the queried rows
for row in rows:
    print(row)
# Out:
# (1, 'Alice', 31, 'HR')

# %%
cursor.execute('''
               UPDATE users
               SET age = 31
                WHERE name = 'Alice'
               ''')

connection.commit()

# %%
cursor.execute('''
               Delete From users
                WHERE name = 'Bob'
                
               ''')
connection.commit()

# %%
connection = sqlite3.connect('sales_data.db')

cursor = connection.cursor()

cursor.execute('''
Create Table If Not Exists sales (
    id INTEGER PRIMARY KEY,
    date TEXT Not Null,
    product TEXT Not Null,
    sales INTEGER,
    region TEXT Not Null
)               
               ''')

sales_data = [
    ('2023-01-01', 'Product1', 100, 'North'),
    ('2023-01-02', 'Product2', 150, 'South'),
    ('2023-01-03', 'Product3', 200, 'East'),
    ('2023-01-04', 'Product4', 250, 'West')
]

cursor.executemany('''
Insert Into sales (date, product, sales, region) Values (?, ?, ?, ?)
                ''', sales_data)

connection.commit()

# %%
cursor.execute('Select * From sales')
rows = cursor.fetchall()


### print the queried rows
for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'Product1', 100, 'North')
# (2, '2023-01-02', 'Product2', 150, 'South')
# (3, '2023-01-03', 'Product3', 200, 'East')
# (4, '2023-01-04', 'Product4', 250, 'West')

# %%
#Permanently close the connection
connection.close()
